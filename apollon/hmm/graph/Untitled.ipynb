# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %load_ext autoreload

# %%
# %autoreload 1
# %aimport grapher

# %%
from apollon import io

# %%
mod = io.load('/Users/michael/data/ESRA/EAn051-A1.hmm')

# %%
labels = np.round(mod.lambda_, 3)
tpm = mod.gamma_

# %%
fig, ax, G = grapher.draw(*mod.theta)

# %%
imshow(mod.gamma_, cmap='jet')

# %%
mod.gamma_
# Out:
# array([[0.26887938, 0.48415521, 0.13794006, 0.10902536],
#        [0.34706392, 0.44290607, 0.08403726, 0.12599276],
#        [0.43593638, 0.24560424, 0.17453815, 0.14392123],
#        [0.15007236, 0.40697005, 0.27140004, 0.17155755]])
